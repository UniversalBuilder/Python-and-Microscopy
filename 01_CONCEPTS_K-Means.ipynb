# %% [markdown]
# # K-Means and seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### code snippet for nbconvert (build a pdf or html printable output)

# %%
ip = get_ipython()
ibe = ip.configurables[-1]
ibe.figure_formats = {"pdf", "png"}

# %% [markdown]
# ### View the dataset using seaborn

# %%
plt.style.use("seaborn-talk")
fig, ax = plt.subplots(figsize=(10, 10))

df = pd.read_excel("data/kmeans.xlsx")

sns.regplot(x=df["X"], y=df["Y"])

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=3, init="k-means++", max_iter=300, n_init=10, random_state=0)

model = km.fit(df)

predictions = km.predict(df)

fig2, ax2 = plt.subplots(figsize=(10, 10))

plt.scatter(df["X"], df["Y"], c=predictions, s=100, cmap="viridis")
plt.scatter(
    km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], s=300, c="red", alpha=0.5
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f6f831a85166> in <module>
#       3 km = KMeans(n_clusters=3, init="k-means++", max_iter=300, n_init=10, random_state=0)
#       4
# ----> 5 model = km.fit(df)
#       6
#       7 predictions = km.predict(df)
#
# NameError: name 'df' is not defined
